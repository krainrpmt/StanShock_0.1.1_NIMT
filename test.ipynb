# %%
import cantera as ct
gas1 = ct.Solution('gri30.yaml')

# %%
gas1.TPX = 296.15, 0.1*100000, 'H2:15, O2:17.9, AR:67.1'

gas1()
gamma = gas1.cp_mass/gas1.cv_mass
print(""gamma)
# Out:
#   gri30:
#
#        temperature   296.15 K
#           pressure   10000 Pa
#            density   0.13336 kg/m^3
#   mean mol. weight   32.836 kg/kmol
#    phase of matter   gas
#
#                           1 kg             1 kmol
#                      ---------------   ---------------
#           enthalpy           -1433.1            -47059  J
#    internal energy            -76421       -2.5094e+06  J
#            entropy            5676.5         1.864e+05  J/K
#     Gibbs function       -1.6825e+06       -5.5249e+07  J
#  heat capacity c_p             716.5             23527  J/K
#  heat capacity c_v            463.29             15213  J/K
#
#                       mass frac. Y      mole frac. X     chem. pot. / RT
#                      ---------------   ---------------   ---------------
#                 H2         0.0092093              0.15            -19.93
#                 O2           0.17443             0.179            -28.71
# ...
